# %%
import subprocess
import re
import string
from collections import OrderedDict

import numpy as np
import pandas as pd

import svm
from sklearn import naive_bayes

# %%
def fit_naive_bayes_model(matrix, labels):
    matrix = matrix.T
    k, m = matrix.shape
    mat_1 = matrix * labels
    mat_0 = matrix * (1 - labels)
    phi_1 = (mat_1.sum(axis=1) + 1) / (mat_1.sum() + k)
    phi_0 = (mat_0.sum(axis=1) + 1) / (mat_0.sum() + k)
    phi_y = labels.mean()
    return phi_1, phi_0, phi_y

def predict_from_naive_bayes_model(model, matrix):
    matrix = matrix.T
    phi_1, phi_0, phi_y = model

    k = phi_1.shape[0]
    phi_1_log, phi_0_log, phi_y_log, phi_y_0_log = np.log(phi_1), np.log(phi_0), np.log(phi_y), np.log(1 - phi_y)
    return (matrix * phi_1_log.reshape(k, 1)).sum(axis=0) + phi_y_log > \
           (((matrix * phi_0_log.reshape(k, 1)).sum(axis=0) + phi_y_0_log) * 1.05)

# %%
def normalize_name(name):
    replaces = OrderedDict((
        ('iy', 'i'),
        ('ei', 'i'),
        ('ey', 'ei'),
        ('q', 'gh'),
        ('oo', 'u'),
        ('ou', 'u'),
        ('u', 'o'),
        ('y', 'i'),
        ('0', 'o'),
    ))
    name = '_'.join(re.findall('[a-z0]+', name.lower()))
    for from_str, to_str in replaces.items():
        name = name.replace(from_str, to_str)

    name = re.sub('({})'.format('|'.join('%s{2,}' % ch for ch in string.ascii_lowercase)), lambda x: x.group(1)[0], name)

    return name

# %%
finglish_to_gender = OrderedDict(pd.read_csv('data/final.csv').set_index('pronounce')['gender'].to_dict())
names = list(map(normalize_name, finglish_to_gender.keys()))
chars = string.ascii_lowercase

# %%
def transform_usernames(usernames):
    matrix = np.zeros((len(usernames), len(names)))
    normalized_usernames = list(map(normalize_name, usernames))
    subprocess.call(['g++', '-std=c++14', 'calculate_matrix.cpp', '-o', 'calculate_matrix'])
    p = subprocess.Popen(['./calculate_matrix'], shell=True, stdout=subprocess.PIPE, stdin=subprocess.PIPE)
    data_to_send = '\n'.join([
        f'{len(usernames)} {len(names)}',
        ' '.join(names),
        '\n'.join(normalized_usernames),
    ])
    stdout, _ = p.communicate(bytes(data_to_send, 'UTF-8'))
    result = str(stdout, 'UTF-8').split('\n')
    cnt = -1
    for i, username in enumerate(normalized_usernames):
        if not username:
            continue
        cnt += 1
        values = list(map(int, result[cnt].split()))
        for name, (j, value) in zip(names, enumerate(values)):
            assert (value == 0) == (name in username), (name, usernames[i], username, value, i)
            matrix[i][j] = (3 - value) if value <= 3 else 0

    return matrix

# %%
def get_matrix_and_labels(data_path, return_csv=False):
    labeled = pd.read_csv(data_path)
    labeled['gender'] = labeled['gender'].transform(lambda x: 1 if x == 'e' else 0)
    usernames = labeled['username'].to_list()
    labels = np.array(labeled['gender'].to_list())
    matrix = transform_usernames(usernames)
    if return_csv:
        return matrix, labels, labeled
    else:
        return matrix, labels

# %%
matrix, labels = get_matrix_and_labels('data/labeled_people.csv')
valid_matrix, valid_labels, valid_people_data = get_matrix_and_labels('data/test_people.csv', return_csv=True)

# %%
model = fit_naive_bayes_model(matrix, labels)

# %%
def test_model(model):
    predict_labels = predict_from_naive_bayes_model(model, valid_matrix)
    for (predict_label, valid_label), username, label in zip(zip(predict_labels, valid_labels), valid_people_data['username'].to_list(), valid_people_data['gender'].to_list()):
        if predict_label != valid_label:
            print(username, normalize_name(username), predict_label, valid_label)
    print((predict_labels == 1).sum())
    print((valid_labels == 1).sum())
    with open('data/certain_people.csv', 'w') as f:
        data = pd.read_csv('data/test_people.csv')
        f.write(data[predict_labels == 1].to_csv(index=False))
    return ((valid_labels == 0) | (predict_labels == 1)).mean()

# %%
print('naive bayes prediction:', test_model(model) * 100, '%')
# Out:
# mahshammarket mahshamarket False 1
# asal_sly asal_sli True 0
# setaesh.setareh setaesh_setareh True 0
# food_network_by_mili fod_network_bi_mili False 1
# gallery_atr_buckingham galeri_atr_bockingham False 1
# butane_rastaghi botane_rastaghi False 1
# majid.miranii majid_mirani True 0
# offroad.shopp ofroad_shop False 1
# alimobram____ alimobram True 0
# hadi_ebrahimibastami hadi_ebrahimibastami True 0
# amirmojiri4 amirmojiri True 0
# bestboy.parishilton bestboi_parishilton False 1
# yvesmalki ivesmalki True 0
# giordano.matty giordano_mati True 0
# mikeleathers mikeleathers False 1
# peter_casio peter_casio False 1
# ed.sherlock.7 ed_sherlock False 1
# johnaerys johnaeris True 0
# proudfelon prodfelon False 1
# snowwhiteondablock snowhiteondablock True 0
# nikki_tkv niki_tkv True 0
# jamminirene jaminirene True 0
# ashleebhypnotherapy ashlebhipnotherapi True 0
# scaramellodeassis50 scaramelodeasis_o True 0
# laylobrwn lailobrwn True 0
# joseph_desanto_jr joseph_desanto_jr True 0
# nafise68.nr nafise_nr True 0
# mh_hosseynii mh_hoseini True 0
# donya.shiri33 donia_shiri True 0
# mahmodian66 mahmodian True 0
# _zynab_7 zinab True 0
# poria_cj poria_cj True 0
# text_mixo text_mixo False 1
# rouhallahroointan.20 rohalahrointan_o True 0
# imanmashad imanmashad True 0
# berjis.reyhan berjis_reihan True 0
# chechak1400 chechak_o False 1
# bi_kas_khasteh bi_kas_khasteh False 1
# n.sheekari n_shekari False 1
# jahanbakhsh9979 jahanbakhsh True 0
# adafatemeh adafatemeh False 1
# avaznankali avaznankali True 0
# raha_nooraei raha_norai True 0
# fateme.karimi.025 fateme_karimi_o True 0
# ftmh.baniasadii78 ftmh_baniasadi True 0
# samin._.ghorbani1388 samin_ghorbani True 0
# sagha8 sagha False 1
# hodaebadiasl hodaebadiasl True 0
# rangirangi5433 rangirangi True 0
# taniafineart taniafineart True 0
# business_shabani bosines_shabani True 0
# citehpub citehpob False 1
# pedramtorki pedramtorki True 0
# anjoman_brand anjoman_brand False 1
# hero.education hero_edocation True 0
# mehran._baniasadi mehran_baniasadi True 0
# parsweld parsweld False 1
# chaprangino chaprangino False 1
# nouribime noribime True 0
# bazaryabi.online bazariabi_online False 1
# majidnamakinooshabadi majidnamakinoshabadi True 0
# vila.sun vila_son True 0
# naziiiiii_sharbaf nazi_sharbaf True 0
# 3.shekamo shekamo False 1
# yonesghotbi9 ionesghotbi True 0
# yasna_babaei_07 iasna_babai_o True 0
# porotoenamirabbass porotoenamirabas False 1
# ghazal_kw766 ghazal_kw True 0
# tla.tronix tla_tronix False 1
# pouyan_dp poian_dp True 0
# parsha_n parsha_n True 0
# anbeh.jonub anbeh_jonob False 1
# pizzapishkhan pizapishkhan False 1
# mr.iliya.1388 mr_ilia True 0
# aghilebrahimiiii aghilebrahimi True 0
# my_angel292 mi_angel False 1
# dem.7431 dem False 1
# leila.davaloo75 lila_davalo True 0
# anna.hdry ana_hdri True 0
# eyebrow_shakila eiebrow_shakila True 0
# art_leylatorki art_leilatorki True 0
# yare_mehraban__ iare_mehraban False 1
# sanaz_nassajpour sanaz_nasajpor True 0
# khadijbagheri6 khadijbagheri True 0
# sevda.soori sevda_sori True 0
# golboteh6 golboteh True 0
# samina.7585 samina True 0
# faraziin.fan.page farazin_fan_page True 0
# mandana_m.1400 mandana_m_o True 0
# hoseinlatifi1328 hosinlatifi True 0
# craziest_sara craziest_sara True 0
# melika.jd_73 melika_jd True 0
# shopp.lux shop_lox False 1
# mahor_raaaaad mahor_rad True 0
# sorry__yaar____ sori_iar True 0
# rakesh9864567 rakesh False 1
# aysan._.1371 aisan True 0
# mr_mukesh_vaishnav007 mr_mokesh_vaishnavo True 0
# anshu00042021 ansho_o False 1
# afsaneh.moloudpour afsaneh_molodpor True 0
# nooshafarinzare noshafarinzare True 0
# setare_sharghi_iii setare_sharghi_i True 0
# sana_nr_ sana_nr True 0
# arezoo_arayeshi arezo_araieshi False 1
# negarrusta negarosta True 0
# micro.atefeh.jafari micro_atefeh_jafari False 1
# n.a.afshar n_a_afshar False 1
# mehdiramezanee13 mehdiramezane True 0
# fashionthran1 fashionthran False 1
# ni.sh.fa ni_sh_fa False 1
# pouria_fadavi poria_fadavi True 0
# sara_zrfrh sara_zrfrh True 0
# zakarya.__.db zakaria_db True 0
# ab.cdef4583 ab_cdef False 1
# parsa._yadegari parsa_iadegari True 0
# miss._.yazdani_ mis_iazdani True 0
# sirwan.dadgar.mariwan sirwan_dadgar_mariwan True 0
# sirvani.m13 sirvani_m True 0
# miilwd_md milwd_md False 1
# lxalixlp lxalixlp False 1
# amirrtr_yt amirtr_it False 1
# realnimataheri realnimataheri True 0
# qqqwpi768687u ghghghwpi_o False 1
# zaker._.and._.zahed zaker_and_zahed False 1
# mehr_.bt mehr_bt False 1
# tavakoli.matinkh tavakoli_matinkh True 0
# dina.87azar dina_azar True 0
# romin_jj romin_j False 1
# imfiboy imfiboi False 1
# xcyb3rgirlx xcib_rgirlx True 0
# amiirren amiren True 0
# djdancer_max djdancer_max False 1
# shakhseat shakhseat False 1
# ar_shia4555 ar_shia True 0
# iwuvmusic iwovmosic False 1
# kalimdor_ir kalimdor_ir False 1
# 9t9.memes t_memes False 1
# behzadlorca behzadlorca True 0
# dr.__.armin dr_armin True 0
# girl_truckbaz girl_trockbaz True 0
# katisiavashan224 katisiavashan True 0
# aghil_davodi_ aghil_davodi True 0
# armanrehnan armanrehnan True 0
# cod.mobail.022 cod_mobail_o False 1
# alexyalexandrov alexialexandrov False 1
# navidaghabeigi navidaghabigi True 0
# khwrwshkoros khwrwshkoros False 1
# laf_shah.2 laf_shah False 1
# jahesh_t12 jahesh_t False 1
# morr.ezaa mor_eza False 1
# sw.sn321 sw_sn False 1
# s_t_96_31 s_t False 1
# m.alimardani1994 m_alimardani True 0
# masume_shirazi00 masome_shirazio True 0
# soheila.n.psaycologist sohila_n_psaicologist True 0
# npfp992 npfp False 1
# atieh_amini2 atieh_amini True 0
# 46_khd khd False 1
# ________mahmood________ mahmod True 0
# asgharkhoshnood asgharkhoshnod True 0
# ghasedak__57 ghasedak True 0
# shaghayegh.farhani74 shaghaiegh_farhani True 0
# poureghbali58 poreghbali True 0
# negar_1609_ negar_o True 0
# alieza.salmani.61 alieza_salmani True 0
# bahram_.roshani bahram_roshani True 0
# kabiri_tameh_ kabiri_tameh False 1
# m.gsm.j m_gsm_j False 1
# elnare_mpur elnare_mpor False 1
# kiarash.mhmdpuri kiarash_mhmdpori True 0
# aras.fishing aras_fishing False 1
# karestekhdam karestekhdam False 1
# mona_azizi72 mona_azizi True 0
# sata.r2009 sata_r_o False 1
# somayeh_.javid somaieh_javid True 0
# khywmrth1266 khiwmrth False 1
# voltrik voltrik False 1
# dglaviabas dglaviabas False 1
# nazanin_youshani nazanin_ioshani True 0
# noroozy2343 norozi False 1
# alidamani3007 alidamani_o True 0
# g.r.m.diaako g_r_m_diako True 0
# azarpeiravi azarpiravi True 0
# s.yhashem9633 s_ihashem True 0
# aniyana_0522 aniana_o True 0
# arman.voj arman_voj True 0
# fardin_5608_ fardin_o True 0
# setarehchobi setarehchobi True 0
# mehdinaghash1360 mehdinaghash_o True 0
# zoya____eshghe___perspolis zoia_eshghe_perspolis True 0
# ehsan_jalali_ ehsan_jalali True 0
# the_unknown_itself the_onknown_itself False 1
# farimah_gg farimah_g True 0
# solmaz_fhk solmaz_fhk True 0
# arcdecogp arcdecogp True 0
# ahmadkhoshnod7 ahmadkhoshnod True 0
# ronaldo.irani77 ronaldo_irani True 0
# __setayesh_77 setaiesh True 0
# golnaz.dnc golnaz_dnc True 0
# ardestani8485 ardestani True 0
# sadra.sh.1397 sadra_sh True 0
# nikoo_h13 niko_h True 0
# hn_yh1291 hn_ih False 1
# seh2904 seh_o False 1
# olfati_1360 olfati_o False 1
# deniz_drakhshan deniz_drakhshan True 0
# ganodermaorginal.ir ganodermaorginal_ir True 0
# ____dooonya____ donia True 0
# dr_namak dr_namak False 1
# kaiiate.mahde.rasht.ir kaiate_mahde_rasht_ir True 0
# mozhgan.tavousi mozhgan_tavosi True 0
# _mahak_banoo_ mahak_bano True 0
# torajmaadani torajmadani True 0
# rahmat.daei rahmat_dai True 0
# reyhaneh44777 reihaneh True 0
# azizi_dr_11 azizi_dr True 0
# _haghgo haghgo False 1
# seyed.jalal.144 seied_jalal True 0
# abay.anzali.chi abai_anzali_chi True 0
# shirin13972 shirin True 0
# asalbanorasht asalbanorasht True 0
# afsaane_bayat1 afsane_baiat True 0
# a.z.az88a.ali_ebadi a_z_az_a_ali_ebadi True 0
# mahtab56.k mahtab_k True 0
# dokhtar.abann dokhtar_aban True 0
# ryn1374ns rin_ns False 1
# shaghayegh_daily_life shaghaiegh_daili_life True 0
# shahrokh9891 shahrokh True 0
# masumeh_shokrii masomeh_shokri True 0
# r.o.s.e.white9 r_o_s_e_white False 1
# alikhanpaye alikhanpaie True 0
# naatasha1994 natasha True 0
# masoud__jahanbakhsh masod_jahanbakhsh True 0
# signalical signalical False 1
# hrb724 hrb False 1
# bnd1123342 bnd False 1
# hesam_mahmoodi hesam_mahmodi True 0
# abbasshirvani7 abashirvani True 0
# isa_setoodeh68shz isa_setodeh_shz True 0
# amir_akhavan_monfared amir_akhavan_monfared True 0
# the_heart_of_beautiful_nature the_heart_of_beaotifol_natore True 0
# vahdansaghafi vahdansaghafi True 0
# saeidrahimi559 saidrahimi True 0
# miss.hazrati73 mis_hazrati True 0
# amir.hossein_sadoogh87 amir_hosin_sadogh True 0
# mehran_animal_lover mehran_animal_lover True 0
# hasaniehsan138584 hasaniehsan True 0
# itsroyax itsroiax True 0
# fatememoloudi fatememolodi True 0
# mahmuod.911 mahmod True 0
# ebi.taram ebi_taram True 0
# davoudsarvi34 davodsarvi True 0
# alisalimi695 alisalimi True 0
# amin1371rostami amin_rostami True 0
# ghavamhaghi.reza ghavamhaghi_reza True 0
# ahmad_balanoshi2020 ahmad_balanoshi_o_o True 0
# set_rahati_ set_rahati False 1
# aamer6941 amer True 0
# mtz.vln mtz_vln False 1
# mhrnbhmn56 mhrnbhmn False 1
# reza_cod_mobile reza_cod_mobile False 1
# ghomi.zzz ghomi_z False 1
# ldu.nial ldo_nial True 0
# aylar_dshti ailar_dshti True 0
# nnfkaabddbaa nfkabdba False 1
# khosravisara528 khosravisara True 0
# serna_amini631 serna_amini True 0
# mohanastikr1 mohanastikr True 0
# selin_t529 selin_t True 0
# sahelxx1382 sahelx True 0
# flwrns57 flwrns False 1
# reyhaneh_morafa reihaneh_morafa True 0
# zarghani_8059 zarghani_o False 1
# nazila_dance2008 nazila_dance_o True 0
# iisara.sa isara_sa True 0
# m.ha13686 m_ha False 1
# nextt_clipp next_clip False 1
# tahmasbi33 tahmasbi False 1
# aramejan4030 aramejan_o_o True 0
# savaalan_iel savalan_iel True 0
# zkd6_8_7 zkd False 1
# leila___as_ lila_as True 0
# hadis_karavanfar_ hadis_karavanfar True 0
# milad_babaian milad_babaian True 0
# kaveh3621 kaveh True 0
# h.h2068 h_h_o False 1
# mazharmardani mazharmardani True 0
# sirosramezani sirosramezani True 0
# pubg_of_war pobg_of_war False 1
# ashpaziye_maryam ashpazie_mariam False 1
# hormuztour hormoztor True 0
# m.nazari2022 m_nazari_o True 0
# danial.delshad danial_delshad True 0
# hacking._.11228 hacking False 1
# roh1400ff roh_of False 1
# yousefnamvar_1 iosefnamvar True 0
# mr.gheysar mr_gheisar True 0
# silahosini silahosini True 0
# vafaei.minoo vafai_mino True 0
# movahed8804 movahed_o False 1
# mahdi_taban101 mahdi_taban_o True 0
# egbalabbasi egbalabasi False 1
# raza.t.v raza_t_v True 0
# _navid_ns_ navid_ns True 0
# sheida.almasii shida_almasi True 0
# mehdi_abdi_rad mehdi_abdi_rad True 0
# sobhanshahhosseini sobhanshahosini True 0
# keramat_yalame keramat_ialame True 0
# mazyarofficial maziaroficial True 0
# catoonipush catoniposh False 1
# keivanroshani82 kivanroshani True 0
# alitaromiyan alitaromian True 0
# mahdikhaleghei mahdikhaleghi True 0
# sajad_khorsandi.official sajad_khorsandi_oficial True 0
# radinleytani radinleitani True 0
# sharareh.saveh sharareh_saveh True 0
# homayoon.n156 homaion_n True 0
# i.am_abo__ i_am_abo False 1
# leilasmaili84 lilasmaili True 0
# its.a.vin its_a_vin True 0
# zoha565 zoha True 0
# giti__2545 giti True 0
# afagh_monfared afagh_monfared True 0
# roshan_ziyari roshan_ziari True 0
# r.purmomen97 r_pormomen False 1
# soheila_hashemimonavar sohila_hashemimonavar True 0
# beauty.__.time beaoti_time False 1
# perfect_buti perfect_boti False 1
# marjan_mehrniaa marjan_mehrnia True 0
# beauty_salon_eyebrow beaoti_salon_eiebrow False 1
# shahnaz_1648 shahnaz True 0
# masuod.art6 masod_art False 1
# gholnesanbti gholnesanbti True 0
# fereshtehkhoshgam2020 fereshtehkhoshgam_o_o True 0
# me.mehrzadeh me_mehrzadeh False 1
# _mozhdehnourkiiia mozhdehnorkia True 0
# mija.mug mija_mog False 1
# shirin.jan___ shirin_jan True 0
# logo_design_19 logo_design False 1
# saba.a___ saba_a True 0
# faeghe_0258 faeghe_o True 0
# missazghandi misazghandi True 0
# noura._rt nora_rt True 0
# fereshte_dadgar fereshte_dadgar True 0
# saharjahanara_ saharjahanara True 0
# f.mahmooodinasab f_mahmodinasab True 0
# _shhrzad.adn shrzad_adn True 0
# ghazaleh_amir_95 ghazaleh_amir True 0
# neef.art nef_art False 1
# 311
# 186
# naive bayes prediction: 87.03703703703704 %
